# %% [markdown]
# # Presentation
#
# This notebook is used for generating figures for the presentation of the project.

# %%
import numpy as np
import matplotlib.pyplot as plt
from ddro import pg, solvers, benchmark
import os

FIGURE_DIR = os.path.join("..", "doc", "figure")

# %% [markdown]
# We create a toy example to introduce the public to the problem.

# %%
# Reproducibility
np.random.seed(1234)

# Limits of the space
x_lim = (-10, 10)
y_lim = (-10, 10)
num_fac = 10
num_cs = 20
fac_pos = np.stack(
    (
        np.random.uniform(x_lim[0], x_lim[1], num_fac),
        np.random.uniform(y_lim[0], y_lim[1], num_fac),
    ),
    axis=1,
)
cs_pos = np.stack(
    (
        np.random.uniform(x_lim[0], x_lim[1], num_cs),
        np.random.uniform(y_lim[0], y_lim[1], num_cs),
    ),
    axis=1,
)
dd_sup = np.arange(1, 101)  # Demand support
cs_oc = np.random.uniform(5000, 10000, size=num_fac)
fac_cap = np.random.uniform(10, 50, size=num_fac)  # Facility capacities
cs_rev = np.random.normal(150, 10, num_cs)  # Costumer site revenues
cs_pen = np.repeat(250, num_cs)  # Costumer site penalties
t_factor = np.random.uniform(
    2, 3, size=(num_fac, num_cs)
)  # Transportation factor
dist = lambda x, y: np.linalg.norm(x - y)  # L2 distance
## Compute the distances between facilities and costumer sites
## and compute the transportation costs
t_costs = np.empty_like(t_factor)
for i in range(num_fac):
    for j in range(num_cs):
        t_costs[i, j] = t_factor[i, j] * dist(fac_pos[i], cs_pos[j])

flp = pg.FLP(
    nf=num_fac,
    nc=num_cs,
    sd=dd_sup,
    oc=cs_oc,
    tc=t_costs,
    cf=fac_cap,
    rc=cs_rev,
    pc=cs_pen,
)

# %%
# Plot facility and costumer site positions
fig = plt.figure(dpi=200)
ax = fig.add_subplot()
ax.set_title("Facilities & Costumer Sites Positions")
ax.set_xlim(-11, 11)
ax.set_ylim(-11, 11)
# ax.grid(visible=True)
ax.scatter(
    fac_pos[:, 0],
    fac_pos[:, 1],
    c="blue",
    marker="o",
    s=20,
    label=f"Facilities (I={num_fac})",
)
ax.scatter(
    cs_pos[:, 0],
    cs_pos[:, 1],
    c="orange",
    marker="o",
    s=20,
    label=f"Costumer sites (J={num_cs})",
)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.legend()
fig.savefig(os.path.join(FIGURE_DIR, "facility_costumer_site_pos.png"))
fig.show()
# Out:
# /tmp/ipykernel_12426/1140362598.py:28: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
bas_solver = solvers.BASSolver(nf=flp.nf, nc=flp.nc)
dr_solver = solvers.DRSolver(nf=flp.nf, nc=flp.nc)
p_solver = solvers.PSolver()

# %%
bas_solver.solve(flp)
dr_solver.solve(flp)
p_solver.solve(flp)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2588513
# Academic license - for non-commercial use only - expires 2025-11-21
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (linux64 - "Ubuntu 24.04.1 LTS")
#
# CPU model: Intel(R) Core(TM) i5-8300H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 81605 rows, 6260 columns and 478810 nonzeros
# Model fingerprint: 0x0de6d2fe
# Variable types: 6250 continuous, 10 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [7e-01, 2e+05]
#   Objective range  [6e-01, 9e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+05]
# Presolve removed 48191 rows and 2812 columns
# Presolve time: 1.41s
# Presolved: 33414 rows, 3448 columns, 400094 nonzeros
# Variable types: 3438 continuous, 10 integer (10 binary)
# Found heuristic solution: objective -75082.29790
# Root relaxation presolved: 33414 rows, 3448 columns, 400094 nonzeros
#
#
# Root relaxation: objective -3.554237e+09, 4249 iterations, 2.01 seconds (4.81 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 

#
# Cutting planes:
#   Gomory: 4
#   Implied bound: 77
#   MIR: 18
#   Flow cover: 19
#   RLT: 1238
#   Relax-and-lift: 2
#   BQP: 36
#
# Explored 2047 nodes (900891 simplex iterations) in 163.69 seconds (288.32 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: -99427.2 -97728.1 -93559.1 ... -75082.3
# No other solutions better than -99427.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.942718914771e+04, best bound -9.942718914771e+04, gap 0.0000%
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (linux64 - "Ubuntu 24.04.1 LTS")
#
# CPU model: Intel(R) Core(TM) i5-8300H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 81605 rows, 6260 columns and 476685 nonzeros
# Model fingerprint: 0x17790bac
# Variable types: 6250 continuous, 10 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [7e-01, 2e+05]
#   Objective range  [1e+00, 9e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+05]
# Presolve removed 54380 rows and 6175 columns
# Presolve time: 4.21s
# Presolved: 27225 rows, 85 columns, 329175 nonzeros
# Variable types: 75 continuous, 10 integer (10 binary)
# Found heuristic solution: objective -8745.755733
# Root relaxation presolved: 85 rows, 27310 columns, 329260 nonzeros
#
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0         41    -infinity      1.7125227e+09      4s
#        1        160  -2.3095876e+09   1.6186205e+09      4s
#        2        242  -2.1755725e+09   1.5523346e+09      4s
#        3        336  -2.1212410e+09   1.4433161e+09      4s
#        4        446  -2.0198738e+09   1.3864670e+09      4s
#        5        540  -1.8803941e+09   1.3410528e+09      4s
#        6        626  -1.8774087e+09   1.3029007e+09      4s
#        7        738  -1.7828067e+09   1.2793059e+09      4s
#        8        858  -1.7314896e+09   1.5158127e+08      4s
#        9        945  -1.7214873e+09   5.1695816e+07      5s
#       10       1047  -1.5092752e+09   2.5144071e+07      5s
#       11       1150  -1.1956661e+09   1.2474628e+07      5s
#       12       1263  -6.9226098e+08   8.4419195e+06      5s
#       13       1389  -4.3869894e+08   2.1059883e+06      5s
#       14       1496  -1.2958062e+07   1.7483719e+06      5s
#       15       1607  -9.1141974e+06   1.6427401e+06      5s
#       16       1717  -5.8388221e+06   1.5159239e+06      5s
#       17       1815  -4.2668100e+06   1.1224940e+06      5s
#       18       1919  -8.3817328e+05   1.0432226e+06      5s
#       19       2018  -5.6409325e+05   8.1760147e+05      5s
#       20       2127  -4.2671184e+05   6.9476253e+05      5s
#       21       2226  -1.9097362e+05   6.2597084e+05      5s
#       22       2322  -1.1946394e+05   5.1450919e+05      5s
#       23       2460  -9.7287962e+04  -2.2039509e+04      5s
#       24       2626  -9.2802967e+04  -8.2871581e+04      5s
#       25       2765  -9.0477563e+04  -8.7648288e+04      5s
#       26       2911  -8.9764992e+04  -8.8399516e+04      5s
#       27       3048  -8.9699710e+04  -8.9003354e+04      5s
#
# Sifting complete
#
#
# Root relaxation: objective -8.964758e+04, 3188 iterations, 0.30 seconds (0.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -89647.580    0    1 -8745.7557 -89647.580   925%     -    4s
# H    0     0                    -57069.35751 -89647.580  57.1%     -    4s
# H    0     0                    -80124.08696 -89647.580  11.9%     -    4s
# H    0     0                    -87304.55579 -89647.580  2.68%     -    4s
# H    0     0                    -89114.33391 -89647.580  0.60%     -    5s
#
# Cutting planes:
#   MIR: 25
#
# Explored 1 nodes (3188 simplex iterations) in 5.26 seconds (3.35 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: -89114.3 -87304.6 -80124.1 -8745.76
# No other solutions better than -89114.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.911433391428e+04, best bound -8.911433391428e+04, gap 0.0000%
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (linux64 - "Ubuntu 24.04.1 LTS")
#
# CPU model: Intel(R) Core(TM) i5-8300H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 285 rows, 260 columns and 760 nonzeros
# Model fingerprint: 0xe261e96f
# Variable types: 250 continuous, 10 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [8e+01, 9e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 0.0000000
# Presolve removed 250 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 35 rows, 260 columns, 510 nonzeros
# Variable types: 250 continuous, 10 integer (10 binary)
#
# Root relaxation: objective -5.421664e+02, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    -542.1663998 -542.16640  0.00%     -    0s
#
# Explored 1 nodes (47 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -542.166 0
# No other solutions better than -542.166
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.421663997931e+02, best bound -5.421663997931e+02, gap 0.0000%
# True

# %%
# Plot chosen facilities and costumer site
def print_chosen_on_ax(ax, mask):
    nmask = ~mask
    ax.set_title("Chosen Facilities & Costumer Sites")
    ax.set_xlim(-11, 11)
    ax.set_ylim(-11, 11)
    ax.scatter(
        fac_pos[mask, 0],
        fac_pos[mask, 1],
        c="green",
        marker="x",
        s=50,
        label=f"Chosen Facilities (I={mask.sum()})",
    )
    ax.scatter(
        fac_pos[nmask, 0],
        fac_pos[nmask, 1],
        c="blue",
        marker="o",
        s=50,
        label=f"Non-chosen Facilities (I={nmask.sum()})",
    )
    ax.scatter(
        cs_pos[:, 0],
        cs_pos[:, 1],
        c="orange",
        marker="o",
        s=20,
        label=f"Costumer sites (J={num_cs})",
    )
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.legend()


fig = plt.figure(dpi=200, figsize=(10, 4))

bas_ax = fig.add_subplot(1, 3, 1)
bas_chosen_mask = bas_solver.y.astype(bool)
print_chosen_on_ax(bas_ax, bas_chosen_mask)
dr_ax = fig.add_subplot(1, 3, 2)
dr_chosen_mask = dr_solver.y.astype(bool)
print_chosen_on_ax(dr_ax, dr_chosen_mask)
p_ax = fig.add_subplot(1, 3, 3)
p_chosen_mask = p_solver.y.astype(bool)
print_chosen_on_ax(p_ax, p_chosen_mask)
bas_ax.set_title("BASSolver")
dr_ax.set_title("DRSolver")
p_ax.set_title("PSolver")

fig.tight_layout()

fig.savefig(os.path.join(FIGURE_DIR, "chosen_facility_costumer_site_pos.png"))
fig.show()
# Out:
# /tmp/ipykernel_12426/4278524827.py:54: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
ys = [bas_solver.y, dr_solver.y, p_solver.y]
N = 250
objs, ss = benchmark.benchmark(ys, flp, N=N)
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (linux64 - "Ubuntu 24.04.1 LTS")
#
# CPU model: Intel(R) Core(TM) i5-8300H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 137500 rows, 68750 columns and 200000 nonzeros
# Model fingerprint: 0x23c6f710
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 136493 rows and 65729 columns
# Presolve time: 0.05s
# Presolved: 1007 rows, 3021 columns, 3021 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.06 seconds (0.05 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      370   -2.6442299e+07   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      373   -2.6442299e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 373 iterations and 0.11 seconds (0.08 work units)
# Optimal objective -2.644229856e+07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (linux64 - "Ubuntu 24.04.1 LTS")
#
# CPU model: Intel(R) Core(TM) i5-8300H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 137500 rows, 68750 columns and 200000 nonzeros
# Model fingerprint: 0xedb0b588
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 137500 rows and 68750 columns
# Presolve time: 0.04s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0770085e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.08 seconds (0.07 work units)
# Optimal objective -2.077008458e+07
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (linux64 - "Ubuntu 24.04.1 LTS")
#
# CPU model: Intel(R) Core(TM) i5-8300H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 137500 rows, 68750 columns and 200000 nonzeros
# Model fingerprint: 0x91ba2508
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 135215 rows and 61895 columns
# Presolve time: 0.07s
# Presolved: 2285 rows, 6855 columns, 6855 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 0.000e+00
#  Factor NZ  : 8.130e+02 (roughly 1 MB of memory)
#  Factor Ops : 8.130e+02 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.08 seconds (0.06 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      813   -3.8620993e+07   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      816   -3.8620993e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 816 iterations and 0.15 seconds (0.08 work units)
# Optimal objective -3.862099256e+07

# %%
fig = plt.figure(dpi=200, figsize=(8, 4))
axl = fig.add_subplot(1, 2, 1)
axr = fig.add_subplot(1, 2, 2)
labels = ["BASSolver", "DRSolver", "PSolver"]
axl.boxplot(
    x=objs,
    tick_labels=labels,
)
axl.set_ylabel("Cost")
axr.boxplot(x=ss, tick_labels=labels)
axr.set_ylabel("Unsatisfied demand")
fig.tight_layout()
fig.savefig(os.path.join(FIGURE_DIR, "benchmark.png"))
fig.show()
# Out:
# /tmp/ipykernel_12426/1518606089.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
